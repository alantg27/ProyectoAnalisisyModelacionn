# %%
import random

# Función para insertar guiones en posiciones aleatorias
def insertar_guiones(cadena):
    for _ in range(3):
        posicion = random.randint(0, len(cadena) - 1)
        cadena = cadena[:posicion] + '-' + cadena[posicion:]
    return cadena

#Sin extremos
def insertar_guiones_no_extremos(cadena):
    for _ in range(3):
        # Seleccionar una posición aleatoria dentro del rango que no incluya el inicio ni el final
        posicion = random.randint(1, len(cadena) - 2)
        cadena = cadena[:posicion] + '-' + cadena[posicion+1:]
    return cadena


# Crear una lista de matrices con guiones distintos
num_matrices = 12
matrices = []

for _ in range(num_matrices):
    X = "ATCGATCG"
    Y = "GCTAGCTA"
    Z = "TACGTACG"
    matriz = [X, Y, Z]
    matriz_con_guiones = [insertar_guiones(cadena) for cadena in matriz]
    matrices.append(matriz_con_guiones)

# Iterar sobre todas las matrices y realizar las operaciones necesarias
for i, matriz in enumerate(matrices):
    print(f"Matriz {i+1} con guiones:")
    for fila in matriz:
        print(''.join(fila))

    # Inicializar la lista de columnas sin guiones para esta matriz
    columnas_sin_guiones = []
    
    # Verificar si alguna columna no consiste solo de guiones
    for columna in zip(*matriz):
        if any(caracter != '-' for caracter in columna):
            columnas_sin_guiones.append(columna)
    
    # Transponer la lista de columnas sin guiones para obtener la matriz resultante
    matriz_sin_guiones = list(zip(*columnas_sin_guiones))
    
    print(f"\nMatriz {i+1} sin guiones:")
    for fila in matriz_sin_guiones:
        print(''.join(fila))
    
    puntos = 0
    for j in range(len(matriz_sin_guiones[0])):
        caracteres_en_posicion = [fila[j] for fila in matriz_sin_guiones]
        caracteres_no_guion = [caracter for caracter in caracteres_en_posicion if caracter != '-']
        
        # Verificar si hay al menos dos caracteres no guion y si al menos dos son iguales,
        # o si hay tres caracteres no guion y al menos dos son iguales, o si los tres son iguales
        if len(caracteres_no_guion) == 2 and len(set(caracteres_no_guion)) == 1:
            puntos += 1
        elif len(caracteres_no_guion) == 3 and (len(set(caracteres_no_guion)) == 1 or len(set(caracteres_no_guion)) == 2):
            puntos += 1

    print(f"Puntos para la matriz {i+1}: {puntos}\n")
# Out:
# Matriz 1 con guiones:
# -A-TCGAT-CG
# GCTAGC-T--A
# TA--CGTA-CG
#
# Matriz 1 sin guiones:
# -A-TCGATCG
# GCTAGC-T-A
# TA--CGTACG
# Puntos para la matriz 1: 6
#
# Matriz 2 con guiones:
# ATC-G--ATCG
# G-C-TAGC-TA
# T-AC--GTACG
#
# Matriz 2 sin guiones:
# ATC-G--ATCG
# G-C-TAGC-TA
# T-AC--GTACG
# Puntos para la matriz 2: 4
#
# Matriz 3 con guiones:
# --ATCGATC-G
# GCTAG--C-TA
# -T-ACGTA-CG
#
# Matriz 3 sin guiones:
# --ATCGATC-G
# GCTAG--C-TA
# -T-ACGTA-CG
# Puntos para la matriz 3: 4
#
# Matriz 4 con guiones:
# -ATC-GAT-CG
# GC--TAGCT-A
# T-A-C-GTACG
#
# Matriz 4 sin guiones:
# -ATC-GAT-CG
# GC--TAGCT-A
# T-A-C-GTACG
# Puntos para la matriz 4: 4
#
# Matriz 5 con guiones:
# -ATCGATC--G
# -GCTA-G-CTA
# T-A-CGTAC-G
#
# Matriz 5 sin guiones:
# -ATCGATC--G
# -GCTA-G-CTA
# T-A-CGTAC-G
# Puntos para la matriz 5: 3
#
# Matriz 6 con guiones:
# -A--TCGATCG
# --GCTAGCT-A
# TA--CG-TACG
#
# Matriz 6 sin guiones:
# -A--TCGATCG
# --GCTAGCT-A
# TA--CG-TACG
# Puntos para la matriz 6: 6
#
# Matriz 7 con guiones:
# ATC-GATC--G
# -GCTA-G-CTA
# TA-C-GT-ACG
#
# Matriz 7 sin guiones:
# ATC-GATC--G
# -GCTA-G-CTA
# TA-C-GT-ACG
# Puntos para la matriz 7: 3
#
# Matriz 8 con guiones:
# AT-CG--ATCG
# -GCTA-GC-TA
# TAC--G-TACG
#
# Matriz 8 sin guiones:
# AT-CG--ATCG
# -GCTA-GC-TA
# TAC--G-TACG
# Puntos para la matriz 8: 3
#
# Matriz 9 con guiones:
# -ATC-GATC-G
# G-C-TAGC-TA
# TAC-G-T-ACG
#
# Matriz 9 sin guiones:
# -ATC-GATC-G
# G-C-TAGC-TA
# TAC-G-T-ACG
# Puntos para la matriz 9: 3
#
# Matriz 10 con guiones:
# -ATCGA-T-CG
# GCT-AG-C-TA
# -TAC--GTACG
#
# Matriz 10 sin guiones:
# -ATCGA-T-CG
# GCT-AG-C-TA
# -TAC--GTACG
# Puntos para la matriz 10: 5
#
# Matriz 11 con guiones:
# -ATCG-AT-CG
# GCT-AGCT--A
# TAC--GTAC-G
#
# Matriz 11 sin guiones:
# -ATCG-AT-CG
# GCT-AGCT--A
# TAC--GTAC-G
# Puntos para la matriz 11: 5
#
# Matriz 12 con guiones:
# -A-TCGA-TCG
# G-CTAG-CT-A
# T-ACG--TACG
#
# Matriz 12 sin guiones:
# -A-TCGA-TCG
# G-CTAG-CT-A
# T-ACG--TACG
# Puntos para la matriz 12: 5
